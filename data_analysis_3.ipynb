# %%
import pandas as pd

path = 'https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/CO2%20Emissions_Canada.csv'
df = pd.read_csv(path)
df.head(3)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# ...

# %%
df.shape
# Out:
# (7385, 12)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df[['Make','Vehicle Class']]
# Out:
#        Make   Vehicle Class
# 0     ACURA         COMPACT
# 1     ACURA         COMPACT
# 2     ACURA         COMPACT
# 3     ACURA     SUV - SMALL
# 4     ACURA     SUV - SMALL
# ...     ...             ...
# 7380  VOLVO     SUV - SMALL
# 7381  VOLVO     SUV - SMALL
# 7382  VOLVO     SUV - SMALL
# 7383  VOLVO  SUV - STANDARD
# 7384  VOLVO  SUV - STANDARD
#
# [7385 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
df[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
df['Cylinders'].unique()
# Out:
# array([ 4,  6, 12,  8, 10,  3,  5, 16])

# %%
df['Cylinders'].value_counts().plot(kind='pie',autopct='%.f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
# use Make column and perform bar plot
df['Make'].nunique()
# Out:
# 42

# %%
df['Make'].value_counts().head(10).plot(kind='bar')
# Out:
# Make
# FORD             628
# CHEVROLET        588
# BMW              527
# MERCEDES-BENZ    419
# PORSCHE          376
# Name: count, dtype: int64

# %%
# hist plot
df[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
df['CO2 Emissions(g/km)'].describe()
# Out:
# count    7385.000000
# mean      250.584699
# std        58.512679
# min        96.000000
# 25%       208.000000
# 50%       246.000000
# 75%       288.000000
# max       522.000000
# Name: CO2 Emissions(g/km), dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(df['CO2 Emissions(g/km)'],bins = [90,100,200,300,400,500,600])
# Out:
# (array([5.000e+00, 1.488e+03, 4.475e+03, 1.312e+03, 1.020e+02, 3.000e+00]),
#  array([ 90., 100., 200., 300., 400., 500., 600.]),
#  <BarContainer object of 6 artists>)

# %%
df[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
# select numeric features
df.select_dtypes(include='number')[:2]
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0          4                               9.9
# 1             2.4          4                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
df['Fuel Consumption City (L/100 km)'].plot(alpha=.4,color='yellow')
df['Fuel Consumption Hwy (L/100 km)'].plot(alpha=.4,color='red')
df['Fuel Consumption Comb (L/100 km)'].plot(alpha=.4,color='green')
# Out:
# <Axes: >

# %%
df[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
# co2 Em>500
df[df['CO2 Emissions(g/km)']>500]
# Out:
#          Make   Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 4509  BUGATTI  CHIRON    TWO-SEATER             8.0         16          AM7
# 5575  BUGATTI  Chiron    TWO-SEATER             8.0         16          AM7
# 6640  BUGATTI  Chiron    TWO-SEATER             8.0         16          AM7
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 4509         Z                              26.8
# 5575         Z                              26.8
# 6640         Z                              26.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 4509                             16.6                              22.2
# 5575                             16.6                              22.2
# 6640                             16.6                              22.2
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 4509                           13                  522
# 5575                           13                  522
# ...

# %%
df.query('Make=="BUGATTI"')
# Out:
#          Make   Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 4509  BUGATTI  CHIRON    TWO-SEATER             8.0         16          AM7
# 5575  BUGATTI  Chiron    TWO-SEATER             8.0         16          AM7
# 6640  BUGATTI  Chiron    TWO-SEATER             8.0         16          AM7
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 4509         Z                              26.8
# 5575         Z                              26.8
# 6640         Z                              26.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 4509                             16.6                              22.2
# 5575                             16.6                              22.2
# 6640                             16.6                              22.2
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 4509                           13                  522
# 5575                           13                  522
# ...

# %%
df[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
# engin size > 2
df[df['Engine Size(L)']>2]
# Out:
#         Make                              Model            Vehicle Class  \
# 1      ACURA                                ILX                  COMPACT
# 3      ACURA                            MDX 4WD              SUV - SMALL
# 4      ACURA                            RDX AWD              SUV - SMALL
# 5      ACURA                                RLX                 MID-SIZE
# 6      ACURA                                 TL                 MID-SIZE
# ...      ...                                ...                      ...
# 7353  TOYOTA                         Tacoma 4WD     PICKUP TRUCK - SMALL
# 7354  TOYOTA                         Tacoma 4WD     PICKUP TRUCK - SMALL
# 7355  TOYOTA  Tacoma 4WD D-Cab TRD Off-Road/Pro     PICKUP TRUCK - SMALL
# 7356  TOYOTA                             Tundra  PICKUP TRUCK - STANDARD
# 7357  TOYOTA                         Tundra 4WD  PICKUP TRUCK - STANDARD
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# ...

# %%
# check for unique records in Vehicle class
df['Vehicle Class'].nunique()
# Out:
# 16

# %%
df['Vehicle Class'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Vehicle Class'>

# %%
# cylinder count >10
df[(df['Cylinders']>10 ) | (df['Fuel Consumption City (L/100 km)']<11)]['Model'].unique()

#df['Fuel Consumption Comb (L/100 km)'].mean()
# Out:
# array(['ILX', 'ILX HYBRID', 'TSX', '4C', 'DB9', 'RAPIDE', 'VANQUISH',
#        'A4', 'A4 QUATTRO', 'A5 QUATTRO', 'A6 QUATTRO TDI (modified)',
#        'A7 QUATTRO TDI (modified)', 'A8 TDI (modified)', 'A8L',
#        'A8L TDI (modified)', 'Q5 TDI (modified)', 'Q5 HYBRID',
#        'TT COUPE QUATTRO', 'TT ROADSTER QUATTRO', 'CONTINENTAL GT',
#        'CONTINENTAL GTC', 'CONTINENTAL GT SPEED CONVERTIBLE',
#        'FLYING SPUR', '320i', '320i xDRIVE', '328d xDRIVE',
#        '328d xDRIVE TOURING', '328i', '328i xDRIVE',
#        '328i xDRIVE GRAN TURISMO', '328i xDRIVE TOURING', '428i COUPE',
#        '428i xDRIVE COUPE', '528i', '528i xDRIVE', '535d xDRIVE', '760Li',
#        'ACTIVEHYBRID 3', 'ACTIVEHYBRID 5', 'ACTIVEHYBRID 7L',
#        'X1 xDRIVE28i', 'Z4 sDRIVE28i', 'ENCORE', 'ENCORE AWD',
#        'LACROSSE eASSIST', 'REGAL eASSIST', 'ATS', 'CRUZE',
#        'CRUZE DIESEL', 'CRUZE ECO', 'EQUINOX', 'IMPALA ECO', 'MALIBU',
# ...

# %%
df.groupby(['Vehicle Class']).max()['CO2 Emissions(g/km)']
# Out:
# Vehicle Class
# COMPACT                     404
# FULL-SIZE                   404
# MID-SIZE                    465
# MINICOMPACT                 365
# MINIVAN                     296
# PICKUP TRUCK - SMALL        331
# PICKUP TRUCK - STANDARD     414
# SPECIAL PURPOSE VEHICLE     298
# STATION WAGON - MID-SIZE    386
# STATION WAGON - SMALL       382
# SUBCOMPACT                  392
# SUV - SMALL                 353
# SUV - STANDARD              476
# TWO-SEATER                  522
# VAN - CARGO                 396
# VAN - PASSENGER             488
# Name: CO2 Emissions(g/km), dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
#Q. Count for Vehicle Type = "SUV - SMALL" whose CO2 Emission is less than 230
df[(df['Vehicle Class'] == 'SUV - SMALL') & (df['CO2 Emissions(g/km)']<230)]
# Out:
#             Make                  Model Vehicle Class  Engine Size(L)  \
# 42          AUDI              Q5 HYBRID   SUV - SMALL             2.0
# 126          BMW           X1 xDRIVE28i   SUV - SMALL             2.0
# 142        BUICK                 ENCORE   SUV - SMALL             1.4
# 143        BUICK             ENCORE AWD   SUV - SMALL             1.4
# 204    CHEVROLET                EQUINOX   SUV - SMALL             2.4
# ...          ...                    ...           ...             ...
# 7346      TOYOTA  RAV4 AWD TRD Off-Road   SUV - SMALL             2.5
# 7347      TOYOTA        RAV4 Hybrid AWD   SUV - SMALL             2.5
# 7371  VOLKSWAGEN                 Tiguan   SUV - SMALL             2.0
# 7379       VOLVO            XC40 T4 AWD   SUV - SMALL             2.0
# 7380       VOLVO            XC40 T5 AWD   SUV - SMALL             2.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...
