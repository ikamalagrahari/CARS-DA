# %% [markdown]
# # **Mostly Used Python functions**
#
# ##### **Functions** : are used to perform typical operation
#
# Ex. print(),  id(),  type()

# %%
print("Hello World")
# Out:
# Hello World

# %%
num  = 934920834209438028492849234829384029840923840
print(num)
# Out:
# 934920834209438028492849234829384029840923840

# %%
print('Hello all Good evening How r u?','Well today we have a class')
# Out:
# Hello all Good evening How r u? Well today we have a class

# %%
print(100,200,300) # at the place of comma , we are getting space
# Out:
# 100 200 300

# %%
# use escape sequences \n(new line) \t(4 spaces)
print('Hello all \nGood evening \nHow r u?','\nWell today we have a \tclass')
# Out:
# Hello all
# Good evening
# How r u?
# Well today we have a 		class

# %%
print('Name\t\t\tBalance\t\t\tInterest')
# Out:
# Name			Balance			Interest

# %%
# today's
print('today\'s home work')
# Out:
# today's home work

# %%
# monika '7070'
'monika \'7070\''
# Out:
# "monika '7070'"

# %%
'monika "7070"'
# Out:
# 'monika "7070"'

# %%
"monika '7070'"  #if inside ' then outside " n viceversa
# Out:
# "monika '7070'"

# %%
# print(object*,sep=' ',end='\n')
print(100,200,300)
# Out:
# 100 200 300

# %%
# changes separator: it is used between two objects
print(100,200,300,sep='-')
# Out:
# 100-200-300

# %%
print('Python','Java','C++',sep='--.')
# Out:
# Python--.Java--.C++

# %%
# end= newline \n
print('Hello',end='\n\n\n')
print('World')
# Out:
# Hello
#
#
# World

# %%
print('Hello',end=' ')
print('World')
# Out:
# Hello World

# %%
# end(works at end of the object) vs sep (between 2 objects)

# %%
# to check total number of objects
r = [3,4,5,6]
len(r)  # count the number of objects present in the collection/iterable
# Out:
# 4

# %%
s = 'sample python program'
len(s)
# Out:
# 21

# %%
# IMP: We can apply len() only on collections
# ex. list,str,tuple,set,dict, range

# we cant use len() over int float complex boolean
len(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d804d0c4595d> in <cell line: 5>()
#       3
#       4 # we cant use len() over int float complex boolean
# ----> 5 len(100)
#
# TypeError: object of type 'int' has no len()

# %%
len('100')
# Out:
# 3

# %%
# to take input from the user input()
name = input('Enter your name:')
age = input('Enter your age')
print('--------------------')
print('Your name is:',name)
print('Your age is:',age)
# Out:
# Enter your name:Amit
# Enter your age22
# --------------------
# Your name is: Amit
# Your age is: 22

# %%
name,age
# Out:
# ('Amit', '22')

# %%
name = input('Enter your name:')
age = input('Enter your age')
print('--------------------')
print('Your name is:',name,'\nYour age is:',age)
# Out:
# Enter your name:A
# Enter your age33
# --------------------
# Your name is: A
# Your age is: 33

# %%
qty = input('Enter the Qty:')
int(qty) * 4
# Out:
# Enter the Qty:10
# 40

# %%
import time

print('*** Welcome to DMart ***')
time.sleep(2)
nm = input('Enter your name:')
time.sleep(1)
print('Hey',nm,'Welcome to DMart')
print('--------------------')
dal_pr = 50
time.sleep(1)
qnt = int(input('Enter the Dal quantity in Kg:'))
print('Total bill for',qnt,'kg Daal is Rs.',dal_pr*qnt)
# Out:
# *** Welcome to DMart ***
# Enter your name:ajay
# Hey ajay Welcome to DMart
# --------------------
# Enter the Dal quantity in Kg:6
# Total bill for 6 kg Daal is Rs. 300

# %%
# for addition of numbers sum()
salary = [10000,20000,30000,40000]
sum(salary)
# Out:
# 100000

# %%
t = (120,344,560,699,799,199)
sum(t)
# Out:
# 2721

# %%
sum([12.44,5.88,9.11])
# Out:
# 27.43

# %%
# to sort the values sorted(): it sorts in ascending order Low to High
t = (12000,3440,50,6999,79,10,1999)
sorted(t)
# Out:
# [10, 50, 79, 1999, 3440, 6999, 12000]

# %%
# to check the details about a function/object u can use help function
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
sorted(t)
# Out:
# [10, 50, 79, 1999, 3440, 6999, 12000]

# %%
# if we want to sort in descending
sorted(t,reverse=True)
# Out:
# [12000, 6999, 3440, 1999, 79, 50, 10]

# %%
c = ['Mohini','Faiz','Rupali','Samiksha','KD','Veera','Saurav']
sorted(c) # A-Z order
# Out:
# ['Faiz', 'KD', 'Mohini', 'Rupali', 'Samiksha', 'Saurav', 'Veera']

# %%
sorted(c,reverse=True)
# Out:
# ['Veera', 'Saurav', 'Samiksha', 'Rupali', 'Mohini', 'KD', 'Faiz']

# %%
sorted(['z','100','A','900','a'])
# Out:
# ['100', '900', 'A', 'a', 'z']

# %%
g = ['Sham','sham','amit']
sorted(g)
# Out:
# ['Sham', 'amit', 'sham']

# %%
o = ['a','Z','A','x','z','X']
sorted(o)  # first it sorts A-Z then it goes to a-z
# Out:
# ['A', 'X', 'Z', 'a', 'x', 'z']

# %%
print(sorted(o))
print(sorted(o,reverse=True))

# %%
sorted(o),sorted(o,reverse=True)

# %%
display(sorted(o),sorted(o,reverse=True))

# %%
b = [100,200,'V','A']
sorted(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-033dff7d81af> in <cell line: 2>()
#       1 b = [100,200,'V','A']
# ----> 2 sorted(b)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
b = [100,200,ord('V'),ord('A')]
sorted(b)
# Out:
# [65, 86, 100, 200]
