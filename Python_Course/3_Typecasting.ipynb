# %%
# Membership operator
# to check an object is a member of a collection or not
# Options:  in, not in
# they return boolean values True False

t = [10,200,300,400,55,199]
type(t)
# Out:
# list

# %%
#syntax: object in collection
a = 400
a in t
# Out:
# True

# %%
199 in t
# Out:
# True

# %%
# basically it is used to perform searching operation

# %%
'tata' not in t
# Out:
# True

# %%
'indra' in 'Mahindra and Mahindra'
# Out:
# True

# %%
# Assignment:
# st = 'sare jaha se achha'
# use in, not in options

# %%
# Identity operator:
# is, is not
# they return boolean values True False
# it compares objects on the basis of address
# if address is same return True
# else return False

a = 'sham'
b = 'Sham'

a is b
# Out:
# False

# %%
id(a),id(b)
# Out:
# (133819842208304, 133819842205680)

# %%
p = 10
q = 10
p is q
# Out:
# True

# %%
id(p),id(q)
# Out:
# (133820142240272, 133820142240272)

# %%
p = 10
q = 10.
p is q
# Out:
# False

# %%
id(p),id(q)
# Out:
# (133820142240272, 133819848868048)

# %%
# interview question:
# Address equality: identity operatior- is is not
# Content equality: conditional operator == !=

# %%
a = 100
b = 100.
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
# check id of a ,b
id(a),id(b)
# Out:
# (133820142243152, 133819848869072)

# %% [markdown]
# # **Basic Data types and Data Structures in Python**

# %%
# Numeric : int[0-9] float complex
a = 100
type(a)
# Out:
# int

# %%
b = 23.55
type(b)
# Out:
# float

# %%
c = 3+4j
type(c)
# Out:
# complex

# %%
# boolean: True False
# String: '' ""
# List: []
# Tuple: ()
# Set: {10,} # atleast one object inside
# dict: {key:value}

# %% [markdown]
# # **Typecasting/Type Conversion**
# - changing the type of data from one form to other form

# %%
num = '400'
num
# Out:
# '400'

# %%
type(num)
# Out:
# str

# %%
num + 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e1351a1d6e7c> in <cell line: 1>()
# ----> 1 num + 100
#
# TypeError: can only concatenate str (not "int") to str

# %%
# we need typecasting in such cases where we want to perform some operations
int(num) + 100  #temp
# Out:
# 500

# %%
num
# Out:
# '400'

# %%
num = int(num)  # parmnt
num += 100
num
# Out:
# 500

# %%
type(num)
# Out:
# int

# %%
num_2 = 500  # convert int to str
str(num_2)
# Out:
# '500'

# %%
num_2
# Out:
# 500

# %%
float(num_2)
# Out:
# 500.0

# %%
# convert into list
list(num_2)  # we cant convert single int value into a list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-722d74fefa95> in <cell line: 2>()
#       1 # convert into list
# ----> 2 list(num_2)  # we cant convert single int value into a list
#
# TypeError: 'int' object is not iterable

# %%
n = 45.66
int(n)
# Out:
# 45

# %%
g = 45+2j
float(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-791b931aeba9> in <cell line: 2>()
#       1 g = 45+2j
# ----> 2 float(g)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
list((10,20,30))
# Out:
# [10, 20, 30]

# %%
nms = ('sham','ram','ashish')
list(nms)
# Out:
# ['sham', 'ram', 'ashish']

# %%
j = [10]
j
# Out:
# [10]

# %%
int(j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-d726a29f2d5f> in <cell line: 1>()
# ----> 1 int(j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
b = 45.67777
int(b)
# Out:
# 45

# %%
# when we have float values and we need to restrict upto some decimal places
round(b,2)
# Out:
# 45.68

# %%
round(b)
# Out:
# 46

# %%
# Q. What is Typecasting/Parsing
# Q. Type of Typecasting: Implicit and Explicit type casting
# Implicit type casting is being performed by python itself

# %%
# ex. of Implicit typecasting
12 + 45.0     #int-->float-->complex-->object/str
# Out:
# 57.0

# %%
100/4
# Out:
# 25.0

# %%
10 + (4+5j)
# Out:
# (14+5j)

# %%
# Explicit typecasting is performed by a User

# %%
# %%time
salary = '34556.88'
# add 10% bonus: salary + salary * 0.1
float(salary) + float(salary)*0.1
# Out:
# CPU times: user 39 µs, sys: 5 µs, total: 44 µs
# Wall time: 47.9 µs
# 38012.568

# %%
# %%time
sal = float(salary)
sal + sal*.1
# Out:
# CPU times: user 33 µs, sys: 0 ns, total: 33 µs
# Wall time: 36.5 µs
# 38012.568

# %%
# Number system conversion:
num = 15

# decimal to binary
bin(num)
# Out:
# '0b1111'

# %%
0b1111
# Out:
# 15

# %%
oct(num)
# Out:
# '0o17'

# %%
hex(num)
# Out:
# '0xf'

# %%
0xf
# Out:
# 15

# %%
0b1010
# Out:
# 10

# %%
0o350
# Out:
# 232

# %%
0x120
# Out:
# 288
