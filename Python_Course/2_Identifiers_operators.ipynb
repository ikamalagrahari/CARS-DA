# %% [markdown]
# # **Identifier:**
# - Object: An entity which exist in the memory
# - Identifier: The name given to the object
#
#
# ```
# Ex. a = 100
# a is an idenitifer
# 100 is an object
# ```

# %%
a = 'ira'
b = 300
c = 'Kolhapur'

# %%
print(dir())

# %%
100   # object

# %%
# check the address of an object using id()
id(100)

# %%
'ashish'

# %%
id('ashish')

# %%
a = 100
b = 23.44
c = 'ashish'
d = [1,2,3]
# w.r.t each object a type is assigned
print(type(a))
print(type(b))
print(id(c))
print(type(d))

# %%
# Python is a dynamically typed language
# Means we need not to mention or declare the type of a particular object
# python identify the of an object in runtime

# float f = 5.66  //static typing
# f = 3.333  // dynamic

# %%
n = {10.0+4j}
type(n)

# %% [markdown]
# - a-z A-Z are valid identifiers
# - _ underscore is a valid identifier
# - number as suffix is valid ex. z_3 = 'Lama2'
# - number as prefix is invalid ex. 4v = 'victor'
# - Special symbols and chars. are invalid
# - Reserved keywords are invalid
# - numbers are not allowed
# - space is invalid

# %%
bank_info = 'SBI Katraj Branch 2123123'
bank_info

# %%
branch3 = 'Shop number 111'
branch3

# %%
3branch = 'Shop number 111'
3branch

# %%
3 = 100  # not valid

# %%
first!name = 'Aniket'  #special symbols/chars are invalid

# %%
as = 450  # reserved keywords

# %%
# Python is a CASE Sensitive language
a = 100
A = 200
print(a)
print(A)

# %% [markdown]
# # **Operators**: Used to perform operations

# %%
# Arithmatic Operator: + - * / // % **
a = 10
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)  # floor division
print(a%b) # remainder
print(a**b) # power of 10^3

# %%
8/3

# %%
8//3

# %%
9//4

# %%
3**3  # 3 cube

# %%
# Assignment Operator += -= *= /= %= //= **=
num = 100
num

# %%
num + 50

# %%
num

# %%
# num = num  + 50
num += 50  # changes are parmnt.
num

# %%
num *= 2
num

# %%
# Assignment: -= *= /= %= //= **=

# %%
num -= 50

# %%
num

# %%
# COmparison/ Conditional operators:
# Ex. < > <= >= == !=
# basically we get the output as a Boolean value: True False
# these operators compare the objects

'python' == 'Python'

# %%
45 > 43.33

# %%
100 !=  400

# %%
# Logical operator: it also returns boolean values
# and or not
True and False

# %%
# Truth table for and operator
# True True - True
# True False - False
# False True - False
# False False - False

# %%
True and True

# %%
True and False

# %%
False and True

# %%
False and False

# %%
# employee record
age = 44
nationality = 'canedian'
if (nationality=='indian') and (age > 18):
  print('Eligible for Vote')
else:
  print('Not Eligible for Vote')

# %%
# OR operator
#  TT T
#  TF T
#  FT T
#  FF F

# %%
place_1 = 'mumbai'
place_2 = 'pune'

if place_1 == 'goa' or place_2 == 'satara':
  print('yes')
else:
  print('no')
# Out:
# no
