# %% [markdown]
# # **Tuple**
# - It has same properties as that of list
# - Except Tuple is immutable
# - Immutable: We cant change in the original object

# %%
# if we have a list
x = [20,30,40]
x

# %%
id(x)

# %%
# add another object
x.append('java')

# %%
x

# %%
# replace 20
x[0] = 'C++'

# %%
x

# %%
# remove 40
#x.remove(40)
x.pop(2)

# %%
x

# %%
id(x)

# %%
# When we are performing some changes in the list then it does in the same address Hence it is called as MUTABLE Data structue

# %%
# Tuple does support this type of operations???
# ANS: NO

# %%
t = (20,30,40)
t

# %%
id(t)

# %%
t[0]

# %%
t[0] = '.NET'

# %%
t.append(100)

# %%
# Which methods tuple has?
# ANS: count and index
print(dir(tuple))

# %%
# lets check list methods
print(dir(list))

# %%
# All list operations are INPLACE==> Permanent
# All tuple operations are NOT INPLACE==> Temporary

# %%
t.index(30)  # return a lowest index

# %%
t.count(20)  # return the count of object present in tuple

# %%
# Q> List vs Tuple
# Q> When to use which one?
# Q> which one is faster and why?
# ans: list hass two memory block and touple has one memory block hence touple in faster
# Q> WHich one is better?--> Depends on Requiremnt

# %% [markdown]
# # **Set**
# - {at least one element}
# - Mutable in nature

# %%
e = {10,20,30,40,50}
print(e)
set1 = {'kala', 'pila'}
set2 = {"ram" , 90 , 30}
print(set1)
set2
# Out:
# {50, 20, 40, 10, 30}
# {'pila', 'kala'}
# {30, 90, 'ram'}

# %%
print(type(e))
type({})
# Out:
# <class 'set'>
# dict

# %%
# how to create an empty set
s = set()
print(s,type(s))

# %%
r = {()}
print(r,type(r))

# %%
# if we check the type of empty {}
type({})  # dictionary

# %%
# Set does not allowe duplicates
e = {10,20,30,40,50,10,20,30,10,10,10,10,10}
e

# %%
# when we want unique records from any collection then use set
# lets k contains emp_ids
k = [101,110,102,101,110,120,121,101]
set(k)

# %%
# Set doesn't preserves sequence order
p = {100,'python',199,0,-1,'A','BB',23.55,9}
p
# Out:
# {-1, 0, 100, 199, 23.55, 9, 'A', 'BB', 'python'}

# %%
# Hash table is a background data structure
# hence it doesnt support indexing and silcing

# %%
e
# Out:
# {10, 20, 30, 40, 50}

# %%
e[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-418f7df63279> in <cell line: 1>()
# ----> 1 e[-1]
#
# TypeError: 'set' object is not subscriptable
