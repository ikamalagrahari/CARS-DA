# %%
# List: []
# Features
# Background data structure: Array
# Indexing[] and slicing[:] supported
# Mutable in nature
# Homo./Heterogeneous elements
# Duplicates allowed
# sequence order gets preserved

# %%
[10,20,20,20,30,10,10,20,20]

# %% [markdown]
# # **a = [100,200,300,400,500]**

# %%
#Q. append() vs extend()
# append adds whole object collectively as a single entity
#f = []
f = list()
f

# %%
f.append('123')
f

# %%
f.append([3,4,5])
f

# %%
# extend adds elemets from that object as a separate entity
f2 = []
f2.extend('123')

# %%
f2

# %%
f2.extend(['python','java','c++'])
f2

# %%
# check current f
f

# %%
# all operations are parmenent opeartions
# lets clear f
f.clear()
f

# %%
#Q. pop() vs remove()
# pop:removes last element by default,pop is index based
# remove: removes specified element, remove method is value based

# %%
help([].pop)

# %%
s = [6,7,8]
s.pop()  # pop returns removed object

# %%
r = [4,5,6]
r.remove(5) # remove doesnt return the removed object

# %%
s,r

# %%
# lets check pop()
a = [1,2,3,4]
a.pop()
a

# %%
# index
a.pop(1)
a

# %%
# index is not present
a.pop(10)

# %%
[].pop()  # thorws an error if we apply pop over empty list

# %%
help([].remove)

# %%
b = [10,20,30,10]
b.remove(10)
b

# %%
b.remove(80)

# %%
print(dir([]))

# %%
# copy(): does shallow copy operation
x = ["A","B",'C']
x

# %%
id(x)

# %%
# create a copy of x
y = x.copy()
y

# %%
id(y)

# %%
display(x,y)

# %%
# pop from x
x.pop()

# %%
display(x,y)

# %%
# deep copy(): elements same but with same id
y

# %%
z = y
z

# %%
display(y,z)

# %%
# remove B from y
y.remove('B')
y

# %%
display(y,z)

# %%
display(id(y),id(z))

# %%
z.clear()

# %%
y,z

# %%
# interview questions
# explain shallow copy/deep copy
# what is the difference between them

# reverse() vs reversed()
# sort() vs sorted()

# %%
t = [200,33,4,0,111,66]
t.sort() # permnt.with ascending
t

# %%
t.sort(reverse=True) # permnt.with descending
t

# %%
t = [200,33,4,0,111,66]
sorted(t) #temp

# %%
t  # original list is unchaged with sorted()

# %%
x = (90,11,200,3,0,-1)
x

# %%
sorted(x)

# %%
x

# %%
sorted({90,11,200,3,0,-1})

# %%
g = ['a','A','b','B']
sorted(g)

# %%
g

# %%
g.sort()

# %%
g

# %%
# asisgnment: check reverse() and reversed()
